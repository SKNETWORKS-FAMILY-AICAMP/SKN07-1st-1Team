# %% [markdown]
# ## 자동차 등록현황 csv loading (df2)

# %%
import csv

# %% [markdown]
# ### pandas 없으면 설치

# %%
#pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 29.6 MB/s eta 0:00:0000:010:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## pandas 에 올리기

# %%
import pandas as pd

# %% [markdown]
# di = {}
# cnt = 0;
# with open("./data/carheadless.csv", "r", encoding='euc-kr') as f:
#     reader = csv.reader(f)
#     cnt = 0
#     for row in reader:
#         if cnt == 0:
#             cnt += 1
#             continue
#
#         try:
#             print(row)
#             df2 = pd.DataFrame(row)
#             pd.concat(df2)
# #                    cursor.execute(sql,[x if len(x) > 0  else None for x in row])
#         except Exception as e:
#             print(e)
#
# print(cnt)

# %% [markdown]
# ### 강사님 코드 도움

# %%
df2 = pd.read_csv("./data/carheadoff.csv", encoding='cp949')

# %% [markdown]
# ## 데이터 올리기 확인

# %%
df2
# Out:
#        2011-01  서울        계      3    969      2    292    616    146    971  \
# 0      2011-01  서울      강남구  163.0  192.0  610.0   31.0  456.0  224.0  229.0
# 1      2011-01  서울      강동구   81.0  107.0   74.0    6.0  261.0  113.0  416.0
# 2      2011-01  서울      강북구  103.0   55.0  201.0    2.0  585.0   57.0  889.0
# 3      2011-01  서울      강서구  111.0  132.0  643.0   15.0  523.0  148.0  277.0
# 4      2011-01  서울      관악구  146.0   94.0  175.0    3.0  508.0   97.0  829.0
# ...        ...  ..      ...    ...    ...    ...    ...    ...    ...    ...
# 44591  2024-10  전북  전주시 덕진구  145.0  152.0  346.0    3.0  214.0  155.0  705.0
# 44592  2024-10  전북  전주시 완산구  340.0  137.0  162.0    1.0  996.0  139.0  498.0
# 44593  2024-10  전북      정읍시  106.0   41.0  127.0    1.0  839.0   43.0   72.0
# 44594  2024-10  전북      진안군  106.0    9.0  575.0   65.0    9.0  746.0   58.0
# 44595  2024-10  전북        계    1.0  970.0  757.0  233.0   12.0  954.0  772.0
#
# ...

# %% [markdown]
# ### 보류

# %% [markdown]
# ## 전기차 등록대수 가져오기

# %%
import requests

# %%
url = "https://chargeinfo.ksga.org/ws/statistics/ev/list?startYearMonth=201006&endYearMonth=202411"

# %%
payload = {
    "startYearMonth": "201006",
    "endYearMonth": "202411",}

# %%
r = requests.get(url, data=payload)

# %%
print(r.json()['criteria'])
# Out:
# {'startYearMonth': '201006', 'endYearMonth': '202411', 'totalItemCount': 159, 'pageItemSize': 2147483647, 'pageCount': 1, 'pageNumber': 0}

# %%
print(r.json()['result'])
# Out:
# [{'yyyyMm': '202407', 'rgn11000': 79548, 'rgn26000': 40368, 'rgn27000': 32631, 'rgn28000': 48073, 'rgn29000': 13820, 'rgn30000': 19933, 'rgn31000': 8883, 'rgn36000': 4905, 'rgn41000': 134741, 'rgn42000': 19611, 'rgn43000': 22759, 'rgn44000': 27979, 'rgn45000': 22494, 'rgn46000': 28386, 'rgn47000': 30810, 'rgn48000': 43013, 'rgn50000': 43117}, {'yyyyMm': '202406', 'rgn11000': 78215, 'rgn26000': 39519, 'rgn27000': 32159, 'rgn28000': 46697, 'rgn29000': 13485, 'rgn30000': 19618, 'rgn31000': 8671, 'rgn36000': 4747, 'rgn41000': 131038, 'rgn42000': 19268, 'rgn43000': 22231, 'rgn44000': 27330, 'rgn45000': 21918, 'rgn46000': 27622, 'rgn47000': 29838, 'rgn48000': 41818, 'rgn50000': 42436}, {'yyyyMm': '202405', 'rgn11000': 76551, 'rgn26000': 38422, 'rgn27000': 31856, 'rgn28000': 45136, 'rgn29000': 13216, 'rgn30000': 18763, 'rgn31000': 8423, 'rgn36000': 4700, 'rgn41000': 127098, 'rgn42000': 19003, 'rgn43000': 21710, 'rgn44000': 26851, 'rgn45000': 21444, 'rgn46000': 27061, 'rgn47000': 2960, 'rgn4
# ...

# %%
rows = r.json()['result']

# %%
df = pd.DataFrame(rows)

# %%
#ji = ['연월', '서울',	'부산',	'대구',	'인천',	'광주',	'대전',	'울산',	'세종',	'경기',	'강원',	'충북',	'충남',	'전북',	'전남',	'경북',	'경남',	'제주', '계']

# %%
# dic ={} # [{'연월': 10}, {'서울': 10},	{'부산':10},	{'대구':10},	{'인천':10},	{'광주':0},	{'대전':0},	{'울산':0},	{'세종':0},	{'경기':0},	{'강원':0},	{'충북':0},	{'충남':0},	{'전북':0},	{'전남':0},	{'경북':0},	{'경남':0},	{'제주':10}, {'계':10}]

# %%
import pandas as pd

# %%
'''
dic = {}
cnt =0;
for x in rows:
#    print(x)
    for xx in x:
        print(ji[cnt], end=' : ')
        print(x[xx])
        #ld[ji[cnt]] = x[xx]
        dic[ji[cnt]] = x[xx]
        cnt += 1
    pd.DataFrame(dic)
    break
    #pd.concat(pd.DataFrame(dic))
    cnt = 0
    print('--------------')
'''
# Out:
# 연월 : 202407
# 서울 : 79548
# 부산 : 40368
# 대구 : 32631
# 인천 : 48073
# 광주 : 13820
# 대전 : 19933
# 울산 : 8883
# 세종 : 4905
# 경기 : 134741
# 강원 : 19611
# 충북 : 22759
# 충남 : 27979
# 전북 : 22494
# 전남 : 28386
# 경북 : 30810
# 경남 : 43013
# 제주 : 43117
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 11
#       9     dic[ji[cnt]] = x[xx]
#      10     cnt += 1
# ---> 11 pd.DataFrame(dic)
#      12 break
#      13 #pd.concat(pd.DataFrame(dic))
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# ...

# %%
#dic
# Out:
# {'연월': '202407',
#  '서울': 79548,
#  '부산': 40368,
#  '대구': 32631,
#  '인천': 48073,
#  '광주': 13820,
#  '대전': 19933,
#  '울산': 8883,
#  '세종': 4905,
#  '경기': 134741,
#  '강원': 19611,
#  '충북': 22759,
#  '충남': 27979,
#  '전북': 22494,
#  '전남': 28386,
#  '경북': 30810,
#  '경남': 43013,
#  '제주': 43117}

# %%
print(r.json())
# Out:
# {'criteria': {'startYearMonth': '201006', 'endYearMonth': '202411', 'totalItemCount': 159, 'pageItemSize': 2147483647, 'pageCount': 1, 'pageNumber': 0}, 'result': [{'yyyyMm': '202407', 'rgn11000': 79548, 'rgn26000': 40368, 'rgn27000': 32631, 'rgn28000': 48073, 'rgn29000': 13820, 'rgn30000': 19933, 'rgn31000': 8883, 'rgn36000': 4905, 'rgn41000': 134741, 'rgn42000': 19611, 'rgn43000': 22759, 'rgn44000': 27979, 'rgn45000': 22494, 'rgn46000': 28386, 'rgn47000': 30810, 'rgn48000': 43013, 'rgn50000': 43117}, {'yyyyMm': '202406', 'rgn11000': 78215, 'rgn26000': 39519, 'rgn27000': 32159, 'rgn28000': 46697, 'rgn29000': 13485, 'rgn30000': 19618, 'rgn31000': 8671, 'rgn36000': 4747, 'rgn41000': 131038, 'rgn42000': 19268, 'rgn43000': 22231, 'rgn44000': 27330, 'rgn45000': 21918, 'rgn46000': 27622, 'rgn47000': 29838, 'rgn48000': 41818, 'rgn50000': 42436}, {'yyyyMm': '202405', 'rgn11000': 76551, 'rgn26000': 38422, 'rgn27000': 31856, 'rgn28000': 45136, 'rgn29000': 13216, 'rgn30000': 18763, 'rgn31000':
# ...

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
print([x for x in rows])
# Out:
# [{'yyyyMm': '202407', 'rgn11000': 79548, 'rgn26000': 40368, 'rgn27000': 32631, 'rgn28000': 48073, 'rgn29000': 13820, 'rgn30000': 19933, 'rgn31000': 8883, 'rgn36000': 4905, 'rgn41000': 134741, 'rgn42000': 19611, 'rgn43000': 22759, 'rgn44000': 27979, 'rgn45000': 22494, 'rgn46000': 28386, 'rgn47000': 30810, 'rgn48000': 43013, 'rgn50000': 43117}, {'yyyyMm': '202406', 'rgn11000': 78215, 'rgn26000': 39519, 'rgn27000': 32159, 'rgn28000': 46697, 'rgn29000': 13485, 'rgn30000': 19618, 'rgn31000': 8671, 'rgn36000': 4747, 'rgn41000': 131038, 'rgn42000': 19268, 'rgn43000': 22231, 'rgn44000': 27330, 'rgn45000': 21918, 'rgn46000': 27622, 'rgn47000': 29838, 'rgn48000': 41818, 'rgn50000': 42436}, {'yyyyMm': '202405', 'rgn11000': 76551, 'rgn26000': 38422, 'rgn27000': 31856, 'rgn28000': 45136, 'rgn29000': 13216, 'rgn30000': 18763, 'rgn31000': 8423, 'rgn36000': 4700, 'rgn41000': 127098, 'rgn42000': 19003, 'rgn43000': 21710, 'rgn44000': 26851, 'rgn45000': 21444, 'rgn46000': 27061, 'rgn47000': 2960, 'rgn4
# ...

# %%
#df = pd.concat([x['yyyyMm'] for x in rows])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df = pd.concat([x['yyyyMm'] for x in rows])
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...

# %% [markdown]
# ## db에 저장하자 df df2

# %% [markdown]
# ### sqlalchemy 없으면 설치

# %%
#pip install sqlalchemy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 14.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.5/599.5 kB 8.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy
from urllib import parse

# %% [markdown]
# ### db 연결

# %%
user = 'team1'
password = '123'
host='192.168.0.95'
port = 3306
database = 'team1'
password = parse.quote_plus(password)
engine = sqlalchemy.create_engine(f"mysql://{user}:{password}@{host}:{port}/{database}")

# %% [markdown]
# ### df 저장

# %%
df.to_sql("ecar", engine, index=False, if_exists="replace")

# %% [markdown]
# ### df2 저장

# %%
df2.to_sql("car", engine, index=False, if_exists="replace")
